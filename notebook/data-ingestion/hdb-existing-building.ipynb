# %% [markdown]
# Dataset from:
# > Housing & Development Board. (2023). HDB Existing Building (2025) [Dataset]. data.gov.sg. Retrieved December 3, 2025 from https://data.gov.sg/datasets/d_16b157c52ed637edd6ba1232e026258d/view

# %% [markdown]
# #### 1. Creates the SQL script

# %% [markdown]
# ```sql
# CREATE TABLE IF NOT EXISTS public.hdb_blocks (
#     objectid BIGINT,
#     blk_no TEXT,
#     street_code TEXT,
#     entity_id BIGINT,
#     postal_code TEXT,
#     inc_crc TEXT,
#     updated_at TEXT,
#     shape_area DOUBLE PRECISION,
#     shape_len DOUBLE PRECISION,
#     geom_4326 geometry(MultiPolygon, 4326),
#     geom_3414 geometry(MultiPolygon, 3414),
#     centroid_4326 geometry(Point, 4326),
#     centroid_3414 geometry(Point, 3414)
# );
# ```

# %% [markdown]
# #### 2. Load the GeoJSON

# %%
import json
import pandas as pd
from shapely.geometry import shape
from shapely.wkt import dumps as wkt_dumps

geo_path = "data/HDBExistingBuilding.geojson"

with open(geo_path, "r") as f:
    gj = json.load(f)

rows = []
for feature in gj["features"]:
    geom = shape(feature["geometry"])
    props = feature["properties"]

    rows.append({
        "objectid": props.get("OBJECTID"),
        "blk_no": props.get("BLK_NO"),
        "street_code": props.get("ST_COD"),
        "entity_id": props.get("ENTITYID"),
        "postal_code": props.get("POSTAL_COD"),
        "inc_crc": props.get("INC_CRC"),
        "updated_at": props.get("FMEL_UPD_D"),
        "shape_area": props.get("SHAPE.AREA"),
        "shape_len": props.get("SHAPE.LEN"),
        "geom_wkt": wkt_dumps(geom),
        "centroid_wkt": wkt_dumps(geom.centroid)
    })

df = pd.DataFrame(rows)
df.head()
# Out:
#    objectid blk_no street_code  entity_id postal_code           inc_crc  \
# 0    898584    514      BUS14E       8235      650514  74585E59F18D2E73
# 1    898585     21      TEG02M       6192      600021  1550C06FF96161F6
# 2    898586     53      MAM00B       9054      320053  6FBC002CCC25E0F0
# 3    898587   686B      CHC17Y      11347      682686  27633E9516C3217B
# 4    898588    697      JUC08W   11051257      640697  6732FD889250ABAA
#
#        updated_at   shape_area   shape_len  \
# 0  20130426120328  1033.685604  253.971941
# 1  20130426120305  1046.092028  397.417077
# 2  20130426120341   465.684209  102.237582
# 3  20130426120329  1164.381084  352.790348
# 4  20201104102827  2044.932108  207.034765
#
#                                             geom_wkt  \
# 0  POLYGON ((103.7529821808343655 1.3544208894918...
# 1  POLYGON ((103.7392355494047109 1.3236971900920...
# 2  POLYGON ((103.8560570595093111 1.3280968319452...
# 3  POLYGON ((103.7483749037369449 1.4048411952521...
# 4  POLYGON ((103.7081363495233575 1.3413769358491...
#
#                                       centroid_wkt
# 0  POINT (103.7525891826131073 1.3544681945247203)
# 1  POINT (103.7392896961472388 1.3236959487788726)
# 2  POINT (103.8560973613317202 1.3282785389346876)
# 3  POINT (103.7485044884540741 1.4046647992030474)
# 4  POINT (103.7080875361858290 1.3416050746094497)

# %% [markdown]
# #### 3. Insert into Postgres

# %%
from sqlalchemy import create_engine, text
import time

import requests
import pandas as pd
import time
from sqlalchemy import create_engine, text
from tqdm.auto import tqdm

# DB connection
engine = create_engine("postgresql://postgres:postgres@postgres-postgresql.postgres:5432/postgres")

BATCH_SIZE = 50
MAX_RETRIES = 3

def insert_batch(batch_df, retry_count=0):
    try:
        with engine.begin() as conn:
            for _, row in batch_df.iterrows():
                conn.execute(text("""
                    INSERT INTO public.hdb_blocks (
                        objectid, blk_no, street_code, entity_id, postal_code,
                        inc_crc, updated_at, shape_area, shape_len,
                        geom_4326, geom_3414,
                        centroid_4326, centroid_3414
                    )
                    VALUES (
                        :objectid, :blk_no, :street_code, :entity_id, :postal_code,
                        :inc_crc, :updated_at, :shape_area, :shape_len,
                        ST_SetSRID(ST_GeomFromText(:geom_4326), 4326),
                        ST_Transform(ST_SetSRID(ST_GeomFromText(:geom_4326), 4326), 3414),
                        ST_SetSRID(ST_GeomFromText(:centroid_4326), 4326),
                        ST_Transform(ST_SetSRID(ST_GeomFromText(:centroid_4326), 4326), 3414)
                    );
                """), {
                    "objectid": row["objectid"],
                    "blk_no": row["blk_no"],
                    "street_code": row["street_code"],
                    "entity_id": row["entity_id"],
                    "postal_code": row["postal_code"],
                    "inc_crc": row["inc_crc"],
                    "updated_at": row["updated_at"],
                    "shape_area": row["shape_area"],
                    "shape_len": row["shape_len"],
                    "geom_4326": row["geom_wkt"],
                    "centroid_4326": row["centroid_wkt"],
                })
        return True
    except Exception as e:
        if retry_count < MAX_RETRIES:
            print(f"⚠ Batch failed: {str(e)[:100]}... Retrying ({retry_count + 1}/{MAX_RETRIES})...")
            time.sleep(2 ** retry_count)  # Exponential backoff
            return insert_batch(batch_df, retry_count + 1)
        else:
            print(f"✗ Batch failed after {MAX_RETRIES} retries")
            return False

# Process in batches
total_batches = (len(df) + BATCH_SIZE - 1) // BATCH_SIZE
successful = 0

for i in range(0, len(df), BATCH_SIZE):
    batch = df.iloc[i:i+BATCH_SIZE]
    batch_num = i // BATCH_SIZE + 1
    print(f"Processing batch {batch_num}/{total_batches}...")
    
    if insert_batch(batch):
        successful += len(batch)
        print(f"  ✔ Batch {batch_num} complete ({successful}/{len(df)} total)")
    else:
        print(f"  ✗ Batch {batch_num} failed")

print(f"\n✔ Completed: {successful}/{len(df)} records inserted")
# Out:
# Processing batch 1/268...
#   ✔ Batch 1 complete (50/13352 total)
# Processing batch 2/268...
#   ✔ Batch 2 complete (100/13352 total)
# Processing batch 3/268...
#   ✔ Batch 3 complete (150/13352 total)
# Processing batch 4/268...
#   ✔ Batch 4 complete (200/13352 total)
# Processing batch 5/268...
#   ✔ Batch 5 complete (250/13352 total)
# Processing batch 6/268...
#   ✔ Batch 6 complete (300/13352 total)
# Processing batch 7/268...
#   ✔ Batch 7 complete (350/13352 total)
# Processing batch 8/268...
#   ✔ Batch 8 complete (400/13352 total)
# Processing batch 9/268...
#   ✔ Batch 9 complete (450/13352 total)
# Processing batch 10/268...
#   ✔ Batch 10 complete (500/13352 total)
# Processing batch 11/268...
#   ✔ Batch 11 complete (550/13352 total)
# Processing batch 12/268...
#   ✔ Batch 12 complete (600/13352 total)
# Processing batch 13/268...
#   ✔ Batch 13 complete (650/13352 total)
# Processing batch 14/268...
#   ✔ Batch 14 complete (700/13352 total)
# Processing batch 15/268...
#   ✔ Batch 15 complete (750/13352 total)
# Processing batch 16/268...
#   ✔ Batch 16 complete (800/13352 total)
# Processing batch 17/268...
#   ✔ Batch 17 complete (850/13352 total)
# Processing batch 18/268...
#   ✔ Batch 18 complete (900/13352 total)
# Processing batch 19/268...
#   ✔ Batch 19 complete (950/13352 total)
# Processing batch 20/268...
#   ✔ Batch 20 complete (1000/13352 total)
# Processing batch 21/268...
#   ✔ Batch 21 complete (1050/13352 total)
# Processing batch 22/268...
#   ✔ Batch 22 complete (1100/13352 total)
# Processing batch 23/268...
#   ✔ Batch 23 complete (1150/13352 total)
# Processing batch 24/268...
#   ✔ Batch 24 complete (1200/13352 total)
# Processing batch 25/268...
#   ✔ Batch 25 complete (1250/13352 total)
# Processing batch 26/268...
#   ✔ Batch 26 complete (1300/13352 total)
# Processing batch 27/268...
#   ✔ Batch 27 complete (1350/13352 total)
# Processing batch 28/268...
#   ✔ Batch 28 complete (1400/13352 total)
# Processing batch 29/268...
#   ✔ Batch 29 complete (1450/13352 total)
# Processing batch 30/268...
#   ✔ Batch 30 complete (1500/13352 total)
# Processing batch 31/268...
#   ✔ Batch 31 complete (1550/13352 total)
# Processing batch 32/268...
#   ✔ Batch 32 complete (1600/13352 total)
# Processing batch 33/268...
#   ✔ Batch 33 complete (1650/13352 total)
# Processing batch 34/268...
#   ✔ Batch 34 complete (1700/13352 total)
# Processing batch 35/268...
#   ✔ Batch 35 complete (1750/13352 total)
# Processing batch 36/268...
#   ✔ Batch 36 complete (1800/13352 total)
# Processing batch 37/268...
#   ✔ Batch 37 complete (1850/13352 total)
# Processing batch 38/268...
#   ✔ Batch 38 complete (1900/13352 total)
# Processing batch 39/268...
#   ✔ Batch 39 complete (1950/13352 total)
# Processing batch 40/268...
#   ✔ Batch 40 complete (2000/13352 total)
# Processing batch 41/268...
#   ✔ Batch 41 complete (2050/13352 total)
# Processing batch 42/268...
#   ✔ Batch 42 complete (2100/13352 total)
# Processing batch 43/268...
#   ✔ Batch 43 complete (2150/13352 total)
# Processing batch 44/268...
#   ✔ Batch 44 complete (2200/13352 total)
# Processing batch 45/268...
#   ✔ Batch 45 complete (2250/13352 total)
# Processing batch 46/268...
#   ✔ Batch 46 complete (2300/13352 total)
# Processing batch 47/268...
#   ✔ Batch 47 complete (2350/13352 total)
# Processing batch 48/268...
#   ✔ Batch 48 complete (2400/13352 total)
# Processing batch 49/268...
#   ✔ Batch 49 complete (2450/13352 total)
# Processing batch 50/268...
#   ✔ Batch 50 complete (2500/13352 total)
# Processing batch 51/268...
#   ✔ Batch 51 complete (2550/13352 total)
# Processing batch 52/268...
#   ✔ Batch 52 complete (2600/13352 total)
# Processing batch 53/268...
#   ✔ Batch 53 complete (2650/13352 total)
# Processing batch 54/268...
#   ✔ Batch 54 complete (2700/13352 total)
# Processing batch 55/268...
#   ✔ Batch 55 complete (2750/13352 total)
# Processing batch 56/268...
#   ✔ Batch 56 complete (2800/13352 total)
# Processing batch 57/268...
#   ✔ Batch 57 complete (2850/13352 total)
# Processing batch 58/268...
#   ✔ Batch 58 complete (2900/13352 total)
# Processing batch 59/268...
#   ✔ Batch 59 complete (2950/13352 total)
# Processing batch 60/268...
#   ✔ Batch 60 complete (3000/13352 total)
# Processing batch 61/268...
#   ✔ Batch 61 complete (3050/13352 total)
# Processing batch 62/268...
#   ✔ Batch 62 complete (3100/13352 total)
# Processing batch 63/268...
#   ✔ Batch 63 complete (3150/13352 total)
# Processing batch 64/268...
#   ✔ Batch 64 complete (3200/13352 total)
# Processing batch 65/268...
#   ✔ Batch 65 complete (3250/13352 total)
# Processing batch 66/268...
#   ✔ Batch 66 complete (3300/13352 total)
# Processing batch 67/268...
#   ✔ Batch 67 complete (3350/13352 total)
# Processing batch 68/268...
#   ✔ Batch 68 complete (3400/13352 total)
# Processing batch 69/268...
#   ✔ Batch 69 complete (3450/13352 total)
# Processing batch 70/268...
#   ✔ Batch 70 complete (3500/13352 total)
# Processing batch 71/268...
#   ✔ Batch 71 complete (3550/13352 total)
# Processing batch 72/268...
#   ✔ Batch 72 complete (3600/13352 total)
# Processing batch 73/268...
#   ✔ Batch 73 complete (3650/13352 total)
# Processing batch 74/268...
#   ✔ Batch 74 complete (3700/13352 total)
# Processing batch 75/268...
#   ✔ Batch 75 complete (3750/13352 total)
# Processing batch 76/268...
#   ✔ Batch 76 complete (3800/13352 total)
# Processing batch 77/268...
#   ✔ Batch 77 complete (3850/13352 total)
# Processing batch 78/268...
#   ✔ Batch 78 complete (3900/13352 total)
# Processing batch 79/268...
#   ✔ Batch 79 complete (3950/13352 total)
# Processing batch 80/268...
# ⚠ Batch failed: (psycopg2.OperationalError) server closed the connection unexpectedly
# 	This probably means the serve... Retrying (1/3)...
# ⚠ Batch failed: (psycopg2.OperationalError) connection to server at "postgres-postgresql.postgres" (10.100.230.47), ... Retrying (2/3)...
# ⚠ Batch failed: (psycopg2.OperationalError) connection to server at "postgres-postgresql.postgres" (10.100.230.47), ... Retrying (3/3)...
# ✗ Batch failed after 3 retries
#   ✗ Batch 80 failed
# Processing batch 81/268...
# ⚠ Batch failed: (psycopg2.OperationalError) connection to server at "postgres-postgresql.postgres" (10.100.230.47), ... Retrying (1/3)...
# ⚠ Batch failed: (psycopg2.OperationalError) connection to server at "postgres-postgresql.postgres" (10.100.230.47), ... Retrying (2/3)...
# ⚠ Batch failed: (psycopg2.OperationalError) connection to server at "postgres-postgresql.postgres" (10.100.230.47), ... Retrying (3/3)...
# ✗ Batch failed after 3 retries
#   ✗ Batch 81 failed
# Processing batch 82/268...
# ⚠ Batch failed: (psycopg2.OperationalError) connection to server at "postgres-postgresql.postgres" (10.100.230.47), ... Retrying (1/3)...
#   ✔ Batch 82 complete (4000/13352 total)
# Processing batch 83/268...
#   ✔ Batch 83 complete (4050/13352 total)
# Processing batch 84/268...
#   ✔ Batch 84 complete (4100/13352 total)
# Processing batch 85/268...
#   ✔ Batch 85 complete (4150/13352 total)
# Processing batch 86/268...
#   ✔ Batch 86 complete (4200/13352 total)
# Processing batch 87/268...
#   ✔ Batch 87 complete (4250/13352 total)
# Processing batch 88/268...
#   ✔ Batch 88 complete (4300/13352 total)
# Processing batch 89/268...
#   ✔ Batch 89 complete (4350/13352 total)
# Processing batch 90/268...
#   ✔ Batch 90 complete (4400/13352 total)
# Processing batch 91/268...
#   ✔ Batch 91 complete (4450/13352 total)
# Processing batch 92/268...
#   ✔ Batch 92 complete (4500/13352 total)
# Processing batch 93/268...
#   ✔ Batch 93 complete (4550/13352 total)
# Processing batch 94/268...
#   ✔ Batch 94 complete (4600/13352 total)
# Processing batch 95/268...
#   ✔ Batch 95 complete (4650/13352 total)
# Processing batch 96/268...
#   ✔ Batch 96 complete (4700/13352 total)
# Processing batch 97/268...
#   ✔ Batch 97 complete (4750/13352 total)
# Processing batch 98/268...
#   ✔ Batch 98 complete (4800/13352 total)
# Processing batch 99/268...
#   ✔ Batch 99 complete (4850/13352 total)
# Processing batch 100/268...
#   ✔ Batch 100 complete (4900/13352 total)
# Processing batch 101/268...
#   ✔ Batch 101 complete (4950/13352 total)
# Processing batch 102/268...
#   ✔ Batch 102 complete (5000/13352 total)
# Processing batch 103/268...
#   ✔ Batch 103 complete (5050/13352 total)
# Processing batch 104/268...
#   ✔ Batch 104 complete (5100/13352 total)
# Processing batch 105/268...
#   ✔ Batch 105 complete (5150/13352 total)
# Processing batch 106/268...
#   ✔ Batch 106 complete (5200/13352 total)
# Processing batch 107/268...
#   ✔ Batch 107 complete (5250/13352 total)
# Processing batch 108/268...
#   ✔ Batch 108 complete (5300/13352 total)
# Processing batch 109/268...
#   ✔ Batch 109 complete (5350/13352 total)
# Processing batch 110/268...
#   ✔ Batch 110 complete (5400/13352 total)
# Processing batch 111/268...
#   ✔ Batch 111 complete (5450/13352 total)
# Processing batch 112/268...
#   ✔ Batch 112 complete (5500/13352 total)
# Processing batch 113/268...
#   ✔ Batch 113 complete (5550/13352 total)
# Processing batch 114/268...
#   ✔ Batch 114 complete (5600/13352 total)
# Processing batch 115/268...
#   ✔ Batch 115 complete (5650/13352 total)
# Processing batch 116/268...
#   ✔ Batch 116 complete (5700/13352 total)
# Processing batch 117/268...
#   ✔ Batch 117 complete (5750/13352 total)
# Processing batch 118/268...
#   ✔ Batch 118 complete (5800/13352 total)
# Processing batch 119/268...
#   ✔ Batch 119 complete (5850/13352 total)
# Processing batch 120/268...
#   ✔ Batch 120 complete (5900/13352 total)
# Processing batch 121/268...
#   ✔ Batch 121 complete (5950/13352 total)
# Processing batch 122/268...
#   ✔ Batch 122 complete (6000/13352 total)
# Processing batch 123/268...
#   ✔ Batch 123 complete (6050/13352 total)
# Processing batch 124/268...
#   ✔ Batch 124 complete (6100/13352 total)
# Processing batch 125/268...
#   ✔ Batch 125 complete (6150/13352 total)
# Processing batch 126/268...
#   ✔ Batch 126 complete (6200/13352 total)
# Processing batch 127/268...
#   ✔ Batch 127 complete (6250/13352 total)
# Processing batch 128/268...
#   ✔ Batch 128 complete (6300/13352 total)
# Processing batch 129/268...
#   ✔ Batch 129 complete (6350/13352 total)
# Processing batch 130/268...
#   ✔ Batch 130 complete (6400/13352 total)
# Processing batch 131/268...
#   ✔ Batch 131 complete (6450/13352 total)
# Processing batch 132/268...
#   ✔ Batch 132 complete (6500/13352 total)
# Processing batch 133/268...
#   ✔ Batch 133 complete (6550/13352 total)
# Processing batch 134/268...
#   ✔ Batch 134 complete (6600/13352 total)
# Processing batch 135/268...
#   ✔ Batch 135 complete (6650/13352 total)
# Processing batch 136/268...
#   ✔ Batch 136 complete (6700/13352 total)
# Processing batch 137/268...
#   ✔ Batch 137 complete (6750/13352 total)
# Processing batch 138/268...
#   ✔ Batch 138 complete (6800/13352 total)
# Processing batch 139/268...
#   ✔ Batch 139 complete (6850/13352 total)
# Processing batch 140/268...
#   ✔ Batch 140 complete (6900/13352 total)
# Processing batch 141/268...
#   ✔ Batch 141 complete (6950/13352 total)
# Processing batch 142/268...
#   ✔ Batch 142 complete (7000/13352 total)
# Processing batch 143/268...
#   ✔ Batch 143 complete (7050/13352 total)
# Processing batch 144/268...
#   ✔ Batch 144 complete (7100/13352 total)
# Processing batch 145/268...
#   ✔ Batch 145 complete (7150/13352 total)
# Processing batch 146/268...
#   ✔ Batch 146 complete (7200/13352 total)
# Processing batch 147/268...
#   ✔ Batch 147 complete (7250/13352 total)
# Processing batch 148/268...
#   ✔ Batch 148 complete (7300/13352 total)
# Processing batch 149/268...
#   ✔ Batch 149 complete (7350/13352 total)
# Processing batch 150/268...
#   ✔ Batch 150 complete (7400/13352 total)
# Processing batch 151/268...
#   ✔ Batch 151 complete (7450/13352 total)
# Processing batch 152/268...
#   ✔ Batch 152 complete (7500/13352 total)
# Processing batch 153/268...
#   ✔ Batch 153 complete (7550/13352 total)
# Processing batch 154/268...
#   ✔ Batch 154 complete (7600/13352 total)
# Processing batch 155/268...
#   ✔ Batch 155 complete (7650/13352 total)
# Processing batch 156/268...
#   ✔ Batch 156 complete (7700/13352 total)
# Processing batch 157/268...
#   ✔ Batch 157 complete (7750/13352 total)
# Processing batch 158/268...
#   ✔ Batch 158 complete (7800/13352 total)
# Processing batch 159/268...
#   ✔ Batch 159 complete (7850/13352 total)
# Processing batch 160/268...
#   ✔ Batch 160 complete (7900/13352 total)
# Processing batch 161/268...
#   ✔ Batch 161 complete (7950/13352 total)
# Processing batch 162/268...
#   ✔ Batch 162 complete (8000/13352 total)
# Processing batch 163/268...
#   ✔ Batch 163 complete (8050/13352 total)
# Processing batch 164/268...
#   ✔ Batch 164 complete (8100/13352 total)
# Processing batch 165/268...
#   ✔ Batch 165 complete (8150/13352 total)
# Processing batch 166/268...
#   ✔ Batch 166 complete (8200/13352 total)
# Processing batch 167/268...
#   ✔ Batch 167 complete (8250/13352 total)
# Processing batch 168/268...
#   ✔ Batch 168 complete (8300/13352 total)
# Processing batch 169/268...
#   ✔ Batch 169 complete (8350/13352 total)
# Processing batch 170/268...
#   ✔ Batch 170 complete (8400/13352 total)
# Processing batch 171/268...
#   ✔ Batch 171 complete (8450/13352 total)
# Processing batch 172/268...
#   ✔ Batch 172 complete (8500/13352 total)
# Processing batch 173/268...
#   ✔ Batch 173 complete (8550/13352 total)
# Processing batch 174/268...
#   ✔ Batch 174 complete (8600/13352 total)
# Processing batch 175/268...
#   ✔ Batch 175 complete (8650/13352 total)
# Processing batch 176/268...
#   ✔ Batch 176 complete (8700/13352 total)
# Processing batch 177/268...
#   ✔ Batch 177 complete (8750/13352 total)
# Processing batch 178/268...
#   ✔ Batch 178 complete (8800/13352 total)
# Processing batch 179/268...
#   ✔ Batch 179 complete (8850/13352 total)
# Processing batch 180/268...
#   ✔ Batch 180 complete (8900/13352 total)
# Processing batch 181/268...
#   ✔ Batch 181 complete (8950/13352 total)
# Processing batch 182/268...
#   ✔ Batch 182 complete (9000/13352 total)
# Processing batch 183/268...
#   ✔ Batch 183 complete (9050/13352 total)
# Processing batch 184/268...
#   ✔ Batch 184 complete (9100/13352 total)
# Processing batch 185/268...
#   ✔ Batch 185 complete (9150/13352 total)
# Processing batch 186/268...
#   ✔ Batch 186 complete (9200/13352 total)
# Processing batch 187/268...
#   ✔ Batch 187 complete (9250/13352 total)
# Processing batch 188/268...
#   ✔ Batch 188 complete (9300/13352 total)
# Processing batch 189/268...
#   ✔ Batch 189 complete (9350/13352 total)
# Processing batch 190/268...
#   ✔ Batch 190 complete (9400/13352 total)
# Processing batch 191/268...
#   ✔ Batch 191 complete (9450/13352 total)
# Processing batch 192/268...
#   ✔ Batch 192 complete (9500/13352 total)
# Processing batch 193/268...
#   ✔ Batch 193 complete (9550/13352 total)
# Processing batch 194/268...
#   ✔ Batch 194 complete (9600/13352 total)
# Processing batch 195/268...
#   ✔ Batch 195 complete (9650/13352 total)
# Processing batch 196/268...
#   ✔ Batch 196 complete (9700/13352 total)
# Processing batch 197/268...
#   ✔ Batch 197 complete (9750/13352 total)
# Processing batch 198/268...
#   ✔ Batch 198 complete (9800/13352 total)
# Processing batch 199/268...
#   ✔ Batch 199 complete (9850/13352 total)
# Processing batch 200/268...
#   ✔ Batch 200 complete (9900/13352 total)
# Processing batch 201/268...
#   ✔ Batch 201 complete (9950/13352 total)
# Processing batch 202/268...
#   ✔ Batch 202 complete (10000/13352 total)
# Processing batch 203/268...
#   ✔ Batch 203 complete (10050/13352 total)
# Processing batch 204/268...
#   ✔ Batch 204 complete (10100/13352 total)
# Processing batch 205/268...
#   ✔ Batch 205 complete (10150/13352 total)
# Processing batch 206/268...
#   ✔ Batch 206 complete (10200/13352 total)
# Processing batch 207/268...
#   ✔ Batch 207 complete (10250/13352 total)
# Processing batch 208/268...
#   ✔ Batch 208 complete (10300/13352 total)
# Processing batch 209/268...
#   ✔ Batch 209 complete (10350/13352 total)
# Processing batch 210/268...
#   ✔ Batch 210 complete (10400/13352 total)
# Processing batch 211/268...
#   ✔ Batch 211 complete (10450/13352 total)
# Processing batch 212/268...
#   ✔ Batch 212 complete (10500/13352 total)
# Processing batch 213/268...
#   ✔ Batch 213 complete (10550/13352 total)
# Processing batch 214/268...
#   ✔ Batch 214 complete (10600/13352 total)
# Processing batch 215/268...
#   ✔ Batch 215 complete (10650/13352 total)
# Processing batch 216/268...
#   ✔ Batch 216 complete (10700/13352 total)
# Processing batch 217/268...
#   ✔ Batch 217 complete (10750/13352 total)
# Processing batch 218/268...
#   ✔ Batch 218 complete (10800/13352 total)
# Processing batch 219/268...
#   ✔ Batch 219 complete (10850/13352 total)
# Processing batch 220/268...
#   ✔ Batch 220 complete (10900/13352 total)
# Processing batch 221/268...
#   ✔ Batch 221 complete (10950/13352 total)
# Processing batch 222/268...
#   ✔ Batch 222 complete (11000/13352 total)
# Processing batch 223/268...
#   ✔ Batch 223 complete (11050/13352 total)
# Processing batch 224/268...
#   ✔ Batch 224 complete (11100/13352 total)
# Processing batch 225/268...
#   ✔ Batch 225 complete (11150/13352 total)
# Processing batch 226/268...
#   ✔ Batch 226 complete (11200/13352 total)
# Processing batch 227/268...
#   ✔ Batch 227 complete (11250/13352 total)
# Processing batch 228/268...
#   ✔ Batch 228 complete (11300/13352 total)
# Processing batch 229/268...
#   ✔ Batch 229 complete (11350/13352 total)
# Processing batch 230/268...
#   ✔ Batch 230 complete (11400/13352 total)
# Processing batch 231/268...
#   ✔ Batch 231 complete (11450/13352 total)
# Processing batch 232/268...
#   ✔ Batch 232 complete (11500/13352 total)
# Processing batch 233/268...
#   ✔ Batch 233 complete (11550/13352 total)
# Processing batch 234/268...
#   ✔ Batch 234 complete (11600/13352 total)
# Processing batch 235/268...
#   ✔ Batch 235 complete (11650/13352 total)
# Processing batch 236/268...
#   ✔ Batch 236 complete (11700/13352 total)
# Processing batch 237/268...
#   ✔ Batch 237 complete (11750/13352 total)
# Processing batch 238/268...
#   ✔ Batch 238 complete (11800/13352 total)
# Processing batch 239/268...
#   ✔ Batch 239 complete (11850/13352 total)
# Processing batch 240/268...
#   ✔ Batch 240 complete (11900/13352 total)
# Processing batch 241/268...
#   ✔ Batch 241 complete (11950/13352 total)
# Processing batch 242/268...
#   ✔ Batch 242 complete (12000/13352 total)
# Processing batch 243/268...
#   ✔ Batch 243 complete (12050/13352 total)
# Processing batch 244/268...
#   ✔ Batch 244 complete (12100/13352 total)
# Processing batch 245/268...
#   ✔ Batch 245 complete (12150/13352 total)
# Processing batch 246/268...
#   ✔ Batch 246 complete (12200/13352 total)
# Processing batch 247/268...
#   ✔ Batch 247 complete (12250/13352 total)
# Processing batch 248/268...
#   ✔ Batch 248 complete (12300/13352 total)
# Processing batch 249/268...
#   ✔ Batch 249 complete (12350/13352 total)
# Processing batch 250/268...
#   ✔ Batch 250 complete (12400/13352 total)
# Processing batch 251/268...
#   ✔ Batch 251 complete (12450/13352 total)
# Processing batch 252/268...
#   ✔ Batch 252 complete (12500/13352 total)
# Processing batch 253/268...
#   ✔ Batch 253 complete (12550/13352 total)
# Processing batch 254/268...
#   ✔ Batch 254 complete (12600/13352 total)
# Processing batch 255/268...
#   ✔ Batch 255 complete (12650/13352 total)
# Processing batch 256/268...
#   ✔ Batch 256 complete (12700/13352 total)
# Processing batch 257/268...
#   ✔ Batch 257 complete (12750/13352 total)
# Processing batch 258/268...
#   ✔ Batch 258 complete (12800/13352 total)
# Processing batch 259/268...
#   ✔ Batch 259 complete (12850/13352 total)
# Processing batch 260/268...
#   ✔ Batch 260 complete (12900/13352 total)
# Processing batch 261/268...
#   ✔ Batch 261 complete (12950/13352 total)
# Processing batch 262/268...
#   ✔ Batch 262 complete (13000/13352 total)
# Processing batch 263/268...
#   ✔ Batch 263 complete (13050/13352 total)
# Processing batch 264/268...
#   ✔ Batch 264 complete (13100/13352 total)
# Processing batch 265/268...
#   ✔ Batch 265 complete (13150/13352 total)
# Processing batch 266/268...
#   ✔ Batch 266 complete (13200/13352 total)
# Processing batch 267/268...
#   ✔ Batch 267 complete (13250/13352 total)
# Processing batch 268/268...
#   ✔ Batch 268 complete (13252/13352 total)
#
# ✔ Completed: 13252/13352 records inserted
